# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# load the data
raw = pd.read_csv('../../data/raw/raw.csv', encoding='latin1', sep=';')

# %%
raw.columns
# Out:
# Index(['[C] Contact: Is system account', '[C] Contact: Is individu account',
#        '[C] Contact: School types', 'Rank', '[C] Contact: Ovatic country',
#        '[C] Contact: Email', '[C] Contact: Gemeente',
#        '[C] Contact: Ovatic city', 'Ovatic activity', '[C] Ovatic season',
#        '[C] Reservation date', 'Startdate', 'Ovatic price type',
#        'Price Currency', 'Price', '[C] Is canceled', '[C] Is free price',
#        '[C] Contact: Passed away', '[C] PPL activity type',
#        'Ovatic ticket: Ovatic ticket', '[C] Contact: [C] Gender',
#        '[C] Contact: Birthdate', '[C] Contact: [C] Age',
#        '[C] Contact: FullID'],
#       dtype='object')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(raw[raw['[C] Contact: Is system account'] == 0]['[C] Contact: Email'].value_counts())
# Out:
# [C] Contact: Email
# carole@kuvolokaal.nl                                 4022
# m.theunissen@operaballet.nl                          3455
# l.vine@operaballet.nl                                1787
# saskia@cultuurhuisheemskerk.nl                       1393
# j.schlichtenhorst@operaballet.nl                     1268
# wendy.tadrous-paulusma@ahk.nl                        1089
# d.eijlander@hetballetorkest.nl                        999
# h.dijkstra@berlagelyceum.eu                           989
# cas@murmellius.nl                                     977
# t.brandsen@operaballet.nl                             865
# fluxus@inkoopfacturen.nl                              847
# e.becker@operaballet.nl                               809
# t.van.dokkumburg@alkwin.nl                            747
# debasterd@hetnet.nl                                   736
# audrey@opera-europa.org                               729
# m.muntwyler@twerenbold.ch                             655
# ...

# %%
# rename columns for readability
raw.columns = ['is_institutional', 'country', 'email', 'municipality', 'city', 'production', 'season', 'purchase_date',
               'start_date', 'ticket_type', 'currency', 'price', 'is_canceled', 'is_free', 'is_dead',
               'activity', 'ticket_num', 'gender', 'birthdate', 'age', 'id']
