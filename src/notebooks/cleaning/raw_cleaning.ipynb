# %%
import sys
sys.path.append("../..")

# %%
# import libraries
import pandas as pd
import numpy as np
import os
from rapidfuzz import process, fuzz

# %%
# import custom modules
from survival.utils import lower_case
from survival.utils import show_all

# %%
# load the data
raw = pd.read_csv('../../data/raw/raw.csv', encoding='latin1', sep=';')

# %%
# rename columns for readability
raw.columns = ['is_institutional', 'is_individual', 'school_type', 'rank', 'country_code', 'email', 'municipality', 'city', 'production', 'season', 'purchase_date',
               'start_date', 'ticket_type', 'currency', 'price', 'is_canceled', 'is_free', 'is_dead',
               'artform', 'ticket_num', 'gender', 'birthdate', 'age', 'id']

# %%
# all string to lower case
raw = lower_case(raw)

# %%
# datetime conversion
raw['purchase_date'] = pd.to_datetime(raw['purchase_date'], dayfirst=True, errors='coerce')
raw['purchase_date'] = pd.to_datetime(raw['purchase_date'].dt.date, dayfirst=True, errors='coerce')

raw['start_date'] = pd.to_datetime(raw['start_date'], dayfirst=True, errors='coerce')

raw['birthdate'] = pd.to_datetime(raw['birthdate'], dayfirst=True, errors='coerce')
raw['birthdate'] = pd.to_datetime(raw['birthdate'].dt.date, dayfirst=True, errors='coerce')

# %%
# delete canceled purchases
raw = raw[raw['is_canceled'] == 0]

# drop unnessesary columns
raw = raw.drop(columns=['is_dead', 'currency', 'is_canceled', 'school_type', 'is_individual', 'is_institutional'])

# retain only ballet and opera
raw = raw[raw['artform'].isin(['ballet', 'opera'])]

# strip all string in production of double spaces
raw['production'] = raw['production'].str.replace('  ', ' ')

# remove the '/ ' in certain production names
raw['production'] = raw['production'].str.replace('/ ', '')

# raw['price'] to float
raw['price'] = raw['price'].str.replace(',', '.')
raw['price'] = pd.to_numeric(raw['price'], errors='coerce')

# delete price outlier
raw = raw[raw['price'] != 2500]

# remove 'seizoen' from season for clarity
raw['season'] = raw['season'].str.replace('seizoen ', '')
raw['season'] = raw['season'].str.replace('-', '_')

# fill missing values of production with dansers van morgen 2022
raw['production'] = raw['production'].fillna('dansers van morgen 2022')

# %%
# streamline production names of flirt events
from survival.constants import flirt_mapping_dict
raw['production'] = raw['production'].replace(flirt_mapping_dict)

# streamline production names of danser van morgen events
raw.loc[raw['production'] == 'dansers van morgen 2022', 'production'] = '21/22 dansers van morgen'
raw.loc[(raw['production'] == 'dansers van morgen') & (raw['start_date'] > '2022-08-01') & (raw['start_date'] < '2023-08-01'), 'production'] = raw['production'].str.replace('dansers van morgen', '22/23 dansers van morgen')
raw.loc[(raw['production'] == 'dansers van morgen') & (raw['start_date'] > '2023-08-01') & (raw['start_date'] < '2024-08-01'), 'production'] = raw['production'].str.replace('dansers van morgen', '23/24 dansers van morgen')

# streamline production name typos
raw.loc[raw['production'] == 'la traviata', 'production'] = '21/22 la traviata'
raw.loc[raw['production'] == '18/19 die zauberfloete', 'production'] = '18/19 die zauberflote'

# standardize 21/22 hans van manen programmes
raw.loc[raw['production'] == '21/22 hans van manen festival progr i', 'production'] = '21/22 hans van manen festival'
raw.loc[raw['production'] == '21/22 hans van manen festival progr ii', 'production'] = '21/22 hans van manen festival'
raw.loc[raw['production'] == '21/22 hans van manen festival progr iii', 'production'] = '21/22 hans van manen festival'
raw.loc[raw['production'] == '21/22 hans van manen festival progr iv', 'production'] = '21/22 hans van manen festival'

# standardize walkure adventure seats
raw.loc[raw['production'] == '19/20 die walkure adventure seats', 'production'] = '19/20 die walküre'

# %%
# load regular programme data
reg = pd.read_csv('../../data/processed/operaballet_reg_prods_clean.csv')

# keep only the productions that are in the regular programme
raw = raw[raw['production'].isin(reg['production'])]

# %%
# map countries
from survival.constants import country_mapping_dict

def map_country(country):
    for key, value in country_mapping_dict.items():
        if country in value:
            return key
    return np.nan

raw['country_code'] = raw['country_code'].apply(map_country)

# %%
# fix municipality names
raw.loc[raw['municipality'] == 'nuenen- gerwen en nederwetten', 'municipality'] = 'nuenen'
raw.loc[raw['municipality'] == 'nuenen. gerwen en nederwetten', 'municipality'] = 'nuenen'
raw.loc[raw['municipality'] == "'s-gravenhage", 'municipality'] = 'den haag'

# %%
cities = pd.read_csv('../../data/processed/cities.csv')

# %%
def get_best_city_match(raw, cities):
    """
    Match city names from raw dataframe with standardized names from cities dataframe
    using fuzzy matching within the same country.
    
    Args:
        raw: Series containing 'city' and 'country_code'
        cities: DataFrame with columns 'name' and 'country_code'
    
    Returns:
        str: Best matching city name or None if no good match found
    """
    try:
        # Check if required fields exist and are not empty
        if pd.isna(raw['city']) or pd.isna(raw['country_code']) or raw['city'].strip() == '':
            return None
        
        # Standardize input
        input_city = raw['city'].strip().lower()
        input_country = raw['country_code'].strip().upper()
        
        # Filter cities by country code
        country_cities = cities[cities['country_code'] == input_country]
        
        if country_cities.empty:
            return None
            
        # Create list of candidate cities
        candidate_cities = country_cities['name'].str.lower().tolist()
        
        if not candidate_cities:
            return None
            
        # Perform fuzzy matching with token_sort_ratio for better handling of word order
        best_match, score, _ = process.extractOne(
            input_city,
            candidate_cities,
            scorer=fuzz.token_sort_ratio,
            score_cutoff=80
        )
        
        if best_match:
            # Return the original case version from the cities dataframe
            original_case = country_cities[country_cities['name'].str.lower() == best_match]['name'].iloc[0]
            return original_case
            
        return None
        
    except Exception as e:
        print(f"Error processing city match: {e}")
        return None

# Apply the function to your dataframe
raw['corrected_city'] = raw.apply(lambda x: get_best_city_match(x, cities), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 54
#      51         return None
#      53 # Apply the function to your dataframe
# ---> 54 raw['corrected_city'] = raw.apply(lambda x: get_best_city_match(x, cities), axis=1)
#
# File ~/Documents/survival/survenv/lib/python3.11/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/Documents/survival/survenv/lib/python3.11/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/Documents/survival/survenv/lib/python3.11/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/Documents/survival/survenv/lib/python3.11/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[36], line 54, in <lambda>(x)
#      51         return None
#      53 # Apply the function to your dataframe
# ---> 54 raw['corrected_city'] = raw.apply(lambda x: get_best_city_match(x, cities), axis=1)
#
# Cell In[36], line 15, in get_best_city_match(raw, cities)
#       2 """
#       3 Match city names from raw dataframe with standardized names from cities dataframe
#       4 using fuzzy matching within the same country.
#    (...)
#      11     str: Best matching city name or None if no good match found
#      12 """
#      13 try:
#      14     # Check if required fields exist and are not empty
# ---> 15     if pd.isna(raw['city']) or pd.isna(raw['country_code']) or raw['city'].strip() == '':
#      16         return None
#      18     # Standardize input
#
# File ~/Documents/survival/survenv/lib/python3.11/site-packages/pandas/core/series.py:1108, in Series.__getitem__(self, key)
#    1105 if isinstance(key, (list, tuple)):
#    1106     key = unpack_1tuple(key)
# -> 1108 if is_integer(key) and self.index._should_fallback_to_positional:
#    1109     warnings.warn(
#    1110         # GH#50617
#    1111         "Series.__getitem__ treating keys as positions is deprecated. "
#    (...)
#    1116         stacklevel=find_stack_level(),
#    1117     )
#    1118     return self._values[key]
#
# KeyboardInterrupt:

# %%
from rapidfuzz import process, fuzz
import pandas as pd

def create_city_mapping(raw_df, cities_df):
    """
    Create city name mapping in three passes:
    1. Exact match using sets
    2. Fuzzy match on city with country filter
    3. Fuzzy match on remaining cities
    """
    # Prepare mappings dictionary
    mappings = {}
    
    # Get unique city-country combinations
    unique_combinations = raw_df[['city', 'country_code']].drop_duplicates()
    
    # Standardize cities dataframe once
    cities_df = cities_df.copy()
    cities_df['name_std'] = cities_df['name'].apply(lambda x: str(x).strip().lower() if pd.notna(x) else None)
    cities_df['country_code'] = cities_df['country_code'].str.upper()
    
    # PASS 1: Exact matching using sets
    print("Pass 1: Exact matching...")
    unmatched = []
    
    # Create dictionary of sets for each country code
    country_city_sets = {}
    city_to_original = {}
    for _, row in cities_df.iterrows():
        country = row['country_code']
        std_name = row['name_std']
        orig_name = row['name']
        
        if country not in country_city_sets:
            country_city_sets[country] = set()
        country_city_sets[country].add(std_name)
        city_to_original[(country, std_name)] = orig_name
    
    # Do exact matching
    for _, row in unique_combinations.iterrows():
        city = str(row['city']).strip().lower() if pd.notna(row['city']) else None
        country = str(row['country_code']).upper() if pd.notna(row['country_code']) else None
        
        if city is None or country is None:
            mappings[(row['city'], row['country_code'])] = None
            continue
            
        # Check if city exists in country set
        if country in country_city_sets and city in country_city_sets[country]:
            mappings[(row['city'], row['country_code'])] = city_to_original[(country, city)]
        else:
            unmatched.append(row)
    
    # PASS 2: Fuzzy matching within country
    print(f"Pass 2: Fuzzy matching within countries for {len(unmatched)} cities...")
    still_unmatched = []
    
    for row in unmatched:
        city = str(row['city']).strip().lower() if pd.notna(row['city']) else None
        country = str(row['country_code']).upper() if pd.notna(row['country_code']) else None
        
        if city is None or country is None:
            mappings[(row['city'], row['country_code'])] = None
            continue
        
        # Get cities for this country
        country_cities = cities_df[cities_df['country_code'] == country]
        
        if not country_cities.empty:
            result = process.extractOne(
                city,
                country_cities['name_std'].tolist(),
                scorer=fuzz.token_sort_ratio,
                score_cutoff=80
            )
            
            if result is not None:  # Check if a match was found
                best_match, score, _ = result
                original_case = country_cities[
                    country_cities['name_std'] == best_match
                ]['name'].iloc[0]
                mappings[(row['city'], row['country_code'])] = original_case
            else:
                still_unmatched.append(row)
        else:
            still_unmatched.append(row)
    
    # PASS 3: Fuzzy matching globally for remaining cities
    print(f"Pass 3: Global fuzzy matching for {len(still_unmatched)} remaining cities...")
    all_cities = cities_df['name_std'].tolist()
    
    for row in still_unmatched:
        city = str(row['city']).strip().lower() if pd.notna(row['city']) else None
        
        if city is None:
            mappings[(row['city'], row['country_code'])] = None
            continue
            
        result = process.extractOne(
            city,
            all_cities,
            scorer=fuzz.token_sort_ratio,
            score_cutoff=75
        )
        
        if result is not None:  # Check if a match was found
            best_match, score, _ = result
            original_case = cities_df[
                cities_df['name_std'] == best_match
            ]['name'].iloc[0]
            mappings[(row['city'], row['country_code'])] = original_case
        else:
            mappings[(row['city'], row['country_code'])] = None
    
    return mappings

def apply_city_corrections(raw_df, cities_df):
    """Apply city corrections to the dataframe"""
    # Create mapping
    mapping = create_city_mapping(raw_df, cities_df)
    
    # Apply corrections
    raw_df['corrected_city'] = raw_df.apply(
        lambda x: mapping.get((x['city'], x['country_code'])), 
        axis=1
    )
    
    # Print summary
    total = len(mapping)
    corrected = sum(1 for v in mapping.values() if v is not None)
    print(f"\nSummary:")
    print(f"Total unique cities: {total}")
    print(f"Successfully matched: {corrected}")
    print(f"Unmatched: {total - corrected}")
    
    return raw_df

def show_corrections(df):
    """Show all corrections made"""
    changes = df[df['city'] != df['corrected_city']][
        ['city', 'corrected_city', 'country_code']
    ].drop_duplicates()
    
    print("\nCorrections made:")
    print(changes)

# %%
# Apply corrections
corrected_df = apply_city_corrections(raw, cities)

# Show what changes were made
show_corrections(corrected_df)
# Out:
# Pass 1: Exact matching...
# Pass 2: Fuzzy matching within countries for 5875 cities...
# Pass 3: Global fuzzy matching for 3673 remaining cities...
#
# Summary:
# Total unique cities: 13106
# Successfully matched: 10925
# Unmatched: 2181
#
# Corrections made:
#                       city corrected_city country_code
# 0            oudebildtzijl           None           nl
# 6                   wormer        cormery           nl
# 11                vreeland        zeeland           nl
# 14              katwijk zh           None           nl
# 18                laren nh          laren           nl
# ...                    ...            ...          ...
# 2120202           andouque        nanuque           fr
# 2120326  akasaka minato-ku           None           jp
# 2121438       kitaku,tokyo           None           jp
# 2121604               baar           None          NaN
# 2121776     the plains, va     the plains           us
#
# [5785 rows x 3 columns]

# %%
# Show all unmatched cities
unmatched = raw[raw['corrected_city'].isna()][['city', 'country_code']].drop_duplicates()
print("All unmatched cities:")

with show_all():
    display(unmatched.value_counts())
# Out:
# All unmatched cities:
# city                                        country_code
# #naam?                                      nl              1
# oudendijk nh                                nl              1
# ouder a/d amstel                            nl              1
# ouder-amstel                                nl              1
# ouderamstel                                 nl              1
# ouderkerk                                   nl              1
# ouderkerk a.d.ijssel                        nl              1
# ouderkerk a/d amstel                        nl              1
# ouderkerk a/d/ amstel                       nl              1
# ouderkerk a:d amstel                        nl              1
# oudheusden                                  nl              1
# oudheuseden                                 nl              1
# oudorp (nh)                                 nl              1
# oudorp nh                                   nl              1
# oudwoude                                    nl              1
# ouroux en morvan                            fr              1
# outremont, qc                               ca              1
# ouyoun                                      lb              1
# overdinkel                                  nl              1
# ovezande                                    nl              1
# oviedo -asturias                            es              1
# oxshott kt22 0qb                            gb              1
# oxshott surrey                              gb              1
# oxton birkenhead merseyside                 gb              1
# oyun city                                   tr              1
# p                                           nl              1
# paasloo                                     nl              1
# palatine, il                                us              1
# palm harbor florida                         us              1
# oudenhoorn                                  nl              1
# oudendijk                                   nl              1
# osseo, wisconsin                            us              1
# oudenbosch                                  nl              1
# osterley middex                             gb              1
# ostrowiec ?w.                               pl              1
# ota,tokyo                                   jp              1
# ota-ku tokyo                                jp              1
# ottawa ontario                              ca              1
# ottawa, ontario                             ca              1
# ottawa,ontario                              ca              1
# ottestad                                    no              1
# ottobrunn                                   de              1
# ottoland                                    nl              1
# otzberg-zipfen                              de              1
# oud ade                                     nl              1
# oud alblas                                  nl              1
# oud beijerland                              nl              1
# oud zuylen                                  nl              1
# oud-alblas                                  nl              1
# oud-annerveen                               nl              1
# ouddorp zh                                  nl              1
# oude meer                                   nl              1
# oude niedorp                                nl              1
# oude-tonge                                  nl              1
# oudebildtzijl                               nl              1
# oudega gem smallingerlnd                    nl              1
# oudega sudwest-fryslan                      nl              1
# oudelande                                   nl              1
# oudemolen dr                                nl              1
# oudemolen nb                                nl              1
# palma d'mallorca                            es              1
# palma de mallorca                           es              1
# palokka                                     fi              1
# palos verdes peninsula                      us              1
# pennsylvania                                us              1
# pensby                                      gb              1
# pequannock                                  us              1
# perelhal-barcelos                           pt              1
# pereln                                      ch              1
# pernis rotterdam                            nl              1
# pernis rt                                   nl              1
# perros guirec                               fr              1
# pesse                                       nl              1
# petach tikva                                il              1
# petah tikva                                 il              1
# petah tiqwa                                 il              1
# petit quevilly                              fr              1
# petit-lancy 1                               ch              1
# pett                                        gb              1
# pfaeffikon sz                               ch              1
# pfinztal                                    de              1
# philadelphia, pennsylvania                  us              1
# philippine                                  nl              1
# phoenix, arizona                            us              1
# phoenix, az                                 us              1
# pi?a                                        pl              1
# piazza garibaldi 10                         it              1
# piedmont, california                        us              1
# piedmont. ca                                us              1
# pieterburen                                 nl              1
# pietersbierum                               nl              1
# penn                                        gb              1
# penghucounty                                tw              1
# pembrokeshire                               gb              1
# paris france                                fr              1
# panevezys                                   lt              1
# papagou, attiki                             gr              1
# papekop                                     nl              1
# parades hana karkur                         il              1
# parainen                                    fi              1
# pardes khana karkur                         il              1
# parid                                       fr              1
# paris 11                                    fr              1
# paris 13                                    fr              1
# paris 15                                    fr              1
# paris 16                                    fr              1
# paris 18                                    fr              1
# park city, utah                             us              1
# pelt                                        be              1
# parkland county, alberta                    ca              1
# partridge green, horsham                    gb              1
# pasadena ca                                 us              1
# pasadena, ca                                us              1
# pasadena. ca                                us              1
# pazmandfalu                                 hu              1
# paço d'arcos                                pt              1
# pedara catania                              it              1
# pedro miguel , horta                        pt              1
# peest                                       nl              1
# peetri alevik rae vald                      fi              1
# peiraias                                    gr              1
# ossnabruck                                  nl              1
# ossenzijl                                   nl              1
# pingjum                                     nl              1
# nul part                                    nl              1
# nur-sultan                                  kz              1
# nuremberg                                   de              1
# nurnberg - zerzabelshof                     de              1
# nussbaumen                                  ch              1
# nuthetal                                    de              1
# nutting lake                                us              1
# nvt                                         nl              1
# nw3 3dr                                     gb              1
# ny                                          us              1
# nyack, new york                             us              1
# nyc                                         us              1
# nyiregyhaza                                 hu              1
# nymegen                                     nl              1
# nørre aaby                                  dk              1
# o milladoiro                                es              1
# o?ech                                       cz              1
# oak park,illinois                           us              1
# oakland california                          us              1
# oakland, ca                                 us              1
# oakland, california                         us              1
# oakville, on                                ca              1
# oakville, ontario                           ca              1
# oaxaca ne                                   us              1
# oberaegeri                                  ch              1
# oberdorf so                                 ch              1
# oberhofen                                   at              1
# oberhonnefeld                               de              1
# nunhem                                      nl              1
# nukata aichi                                jp              1
# oss (nb)                                    nl              1
# nuernberg                                   de              1
# noordwijk aan zee                           nl              1
# noordwijk gn                                nl              1
# noordwijk z-h                               nl              1
# noordwijk zh                                nl              1
# noordwijker                                 nl              1
# noordwyk zh                                 nl              1
# nordre frogn                                no              1
# nordrhein-westfalen - goch                  de              1
# normanton on the wolds, nottighamshire      uz              1
# north chatham                               us              1
# north epping, nsw                           au              1
# north miami, fl                             us              1
# north piddle                                gb              1
# northville, mi                              us              1
# northwich cheshire                          gb              1
# norwalk, ct                                 us              1
# not specified                               nl              1
# notre dame de livoye                        fr              1
# notre-dame de livoye                        fr              1
# notteroy                                    no              1
# nottinghamshire                             gb              1
# nova serrana                                br              1
# noventa padovana                            it              1
# nowe karmonki                               pl              1
# nr. ringwood                                gb              1
# nrw                                         de              1
# nsw sydney                                  au              1
# oberursel (taunus)                          de              1
# oberursel (taunus) - hessen                 de              1
# oberwil b. zug                              ch              1
# odense sø                                   dk              1
# oost- west en middelbeers                   nl              1
# oost-souburg                                nl              1
# oostenrijk                                  at              1
# oosterbierum                                nl              1
# oosterhout (nl)                             nl              1
# oosterhout gld                              nl              1
# oosterwijtwerd                              nl              1
# oosterwolde gld                             nl              1
# oostgraftdijk                               nl              1
# oosthem                                     nl              1
# oostrum lb                                  nl              1
# oostwold gem oldambt                        nl              1
# oostwold westerkwartier                     nl              1
# oostzaan                                    nl              1
# opheers                                     be              1
# oppegård                                    no              1
# or-akiva                                    il              1
# orcas, wa                                   us              1
# oreokastro                                  gr              1
# orlando, fl                                 us              1
# orlando, florida                            us              1
# orono me                                    us              1
# orry la ville                               fr              1
# orvelte                                     nl              1
# osaka city                                  jp              1
# osaka, habikino                             jp              1
# osnabrueck                                  de              1
# oost- souburg                               nl              1
# oost west en middelbeers                    nl              1
# oost souburg                                nl              1
# okkenbroek                                  nl              1
# odoornerveen                                nl              1
# oeffelt                                     nl              1
# oenkerk                                     nl              1
# offenbach a.m.                              de              1
# offenbach am main                           de              1
# offingawier                                 nl              1
# ohaupo                                      nz              1
# ohe en laak                                 nl              1
# ohio                                        us              1
# oiso kanagawa                               jp              1
# oita-shi                                    jp              1
# ojai, ca                                    us              1
# old hickory                                 us              1
# oosstende                                   be              1
# old lyme, connecticut                       us              1
# oldemare                                    nl              1
# oldeouwer                                   nl              1
# olivos - buenos aires                       ar              1
# olmet et villecun                           fr              1
# olso                                        no              1
# olterterp                                   nl              1
# omri 18                                     il              1
# onbekend                                    nl              1
# onigo di pederroba                          it              1
# onnens fr                                   ch              1
# ooltgensplaat                               nl              1
# pineto (te)                                 it              1
# piti                                        us              1
# noordscheschut                              nl              1
# risho-lezion                                il              1
# rishon le-zion                              il              1
# rishon lezion                               il              1
# rishon-lezion                               il              1
# risskov                                     dk              1
# ritthem                                     nl              1
# roadtown tortola                            vg              1
# robelmont                                   be              1
# robert-mayer                                de              1
# rochester, kent                             gb              1
# rochester, mn                               us              1
# rochester, new york                         us              1
# rochester, ny                               us              1
# rochestown, cork                            ie              1
# rockport, ma                                us              1
# rockville, md 20853                         us              1
# roclenge s/geer                             be              1
# roderesch                                   nl              1
# roderwolde                                  nl              1
# rogat                                       nl              1
# roggel                                      nl              1
# rohel                                       nl              1
# romanian                                    ro              1
# room 1343                                   nl              1
# roosdaal                                    be              1
# ropazu novads                               lv              1
# roquebrune cap martin                       fr              1
# roqueredonde                                fr              1
# rishon le zion                              il              1
# ripselaan                                   nl              1
# representative group member                 gb              1
# riniken                                     ch              1
# retranchement                               nl              1
# reutum                                      nl              1
# reykkjavik                                  is              1
# rhhon                                       nl              1
# rhinebeck, ny                               us              1
# rhode st genèse                             be              1
# rhode-saint-genese                          be              1
# rhode-saint-genèse                          be              1
# ri                                          us              1
# richmond surrey                             gb              1
# richmond, london                            gb              1
# richmond, tx                                us              1
# richmond, va                                us              1
# richmond, va.                               us              1
# richmond. bc                                ca              1
# riddarhyttan                                se              1
# rijkevoort                                  nl              1
# rijsenhout                                  nl              1
# rijswijk (gld)                              nl              1
# rijswijk (zh)                               nl              1
# rijswijk gld                                nl              1
# rijswijk nb                                 nl              1
# rijswijk z-h                                nl              1
# rijswijk zh                                 nl              1
# rijswijk zh, the netherlands                nl              1
# rijswijk0650627059                          nl              1
# rilland                                     nl              1
# rorschacherberg                             ch              1
# roseburg, oregon                            us              1
# rosengarten                                 de              1
# roslyn ny                                   us              1
# römerstein                                  de              1
# rüti zh                                     ch              1
# s gravendeel                                nl              1
# s gravenhage                                nl              1
# s gravenzande                               nl              1
# s hertogenbosch                             nl              1
# s pedro do estoril                          pt              1
# s' hertogenbosch                            nl              1
# s'gravenhage                                nl              1
# s'heer hendrikskinderen                     nl              1
# s-gravenhage                                nl              1
# s-gravenhagen                               nl              1
# s. paulo                                    br              1
# sa coma                                     es              1
# saaksum                                     nl              1
# sabac                                       hr              1
# sacramento, ca                              us              1
# safwa                                       sa              1
# sagamihara kanagawa                         jp              1
# sagamihara-shi,minami-ku                    jp              1
# sagamore beach                              us              1
# saginaw, mi                                 us              1
# saguache, co                                us              1
# saimaanharju                                fi              1
# saint - mandé                               fr              1
# saint andre des eaux                        fr              1
# saint andré lez lille                       fr              1
# råde                                        no              1
# rykkinn                                     no              1
# rvk                                         is              1
# roxbury ct                                  us              1
# rosmalen                                    nl              1
# ross-on-wye                                 gb              1
# rossmoor ca                                 us              1
# rosstal                                     de              1
# rossum gld                                  nl              1
# rossum ov                                   nl              1
# rostov on don                               ru              1
# rotstergaast                                nl              1
# rotterdam-albrandswaard                     nl              1
# rougeux                                     fr              1
# rouveen                                     nl              1
# rowlandsgill                                gb              1
# royal exchange nsw                          au              1
# russian federation                          nl              1
# royal oak michigan                          us              1
# royken                                      no              1
# rozieres sur crise                          fr              1
# rsii buillding rooma                        jp              1
# rubenstraat                                 nl              1
# rubi                                        es              1
# rubi barcelona                              es              1
# rue arthur rozier                           fr              1
# rue dubrowski                               fr              1
# rueil mal maison                            nl              1
# rueil malmaison                             fr              1
# rushon lezion                               il              1
# reston, va usa                              us              1
# renton, wa                                  us              1
# piton saint leu                             fr              1
# portland, oregon                            us              1
# portlaoise county laois                     ie              1
# portugaal                                   nl              1
# portugal cove st philips                    ca              1
# posadas, misiones argentina                 ar              1
# potsdam ot neu fahrland                     de              1
# pozna?                                      pl              1
# pozuelo de alarcón, madrid                  es              1
# praag                                       cz              1
# prag                                        cz              1
# prague 10                                   cz              1
# praha                                       cz              1
# praha 1                                     cz              1
# praha 10                                    cz              1
#                                             nl              1
# praha 4                                     cz              1
# praha 5                                     cz              1
# praha 6                                     cz              1
# praha 6 - stresovice                        cz              1
# praha 7                                     cz              1
# prahran, vic                                au              1
# prato (po)                                  it              1
# premier                                     ch              1
# presov                                      sk              1
# preston hitchin                             gb              1
# prevessin                                   fr              1
# princeton, new jerseyusa                    us              1
# prisse                                      fr              1
# portland,or                                 us              1
# portland, or                                us              1
# rembrandt plain                             nl              1
# portland, maine                             us              1
# pittsburgh, pennsylvania                    us              1
# place du tunnel 3                           ch              1
# placentia, ca                               us              1
# placida                                     us              1
# plainsboro                                  us              1
# plasmolen                                   nl              1
# platja d?aro                                es              1
# playa del rey                               us              1
# playa vista                                 us              1
# pleumeur bodou                              fr              1
# plymouth, minnesota                         us              1
# plze?                                       cz              1
# plzen                                       cz              1
# pocono lake                                 us              1
# podleze                                     pl              1
# poleymieux au mont d'or                     fr              1
# polish                                      pl              1
# pology                                      ua              1
# polsbroek                                   nl              1
# pont du chateau                             fr              1
# poortugaal                                  nl              1
# poppenwier                                  nl              1
# port credit                                 ca              1
# port ste foy et ponchapt                    fr              1
# port sydney,  on                            ca              1
# portland maine                              us              1
# portland oregon                             us              1
# providence, ri                              us              1
# providencia, santiago                       cl              1
# provo, ut                                   us              1
# puerto pollensa                             es              1
# raleigh, north carolina                     us              1
# ramat-gan                                   il              1
# ramenki st, 20. apt71                       ru              1
# rancho santa fe, california                 us              1
# randers no                                  dk              1
# randers nv                                  dk              1
# rannana                                     il              1
# raplamaa, estonia                           ee              1
# raritan, nj                                 us              1
# ras al khaimah                              ae              1
# rasnov                                      ro              1
# rasquert                                    nl              1
# ratingen - lintorf                          de              1
# ravel residence                             nl              1
# ravenswaaij                                 nl              1
# ravine des cabris                           fr              1
# rayleigh essex                              gb              1
# reading pa                                  us              1
# rechovot                                    il              1
# red hook ny                                 us              1
# redberth, tenby                             gb              1
# reggio e milia                              it              1
# reggio emilia                               it              1
# regio moskou, shchelkovo                    ru              1
# reguly antal u. 24 04                       tr              1
# reinach, bl                                 ch              1
# rekken                                      nl              1
# rahmt hsron                                 il              1
# rafina                                      ru              1
#                                             gr              1
# pähl-fischen                                de              1
# pulau pinang                                my              1
# pullach                                     de              1
# puntalón                                    es              1
# punthorst                                   nl              1
# purmer                                      nl              1
# purmerend nederland                         nl              1
# purmerland                                  nl              1
# pushkino mn zvyagino                        ru              1
# pushkinskiy raion, poselok chelyskinskiy    ru              1
# puttershoek                                 nl              1
# puyricard                                   fr              1
# puéchabon                                   fr              1
# pérignat sur allier                         fr              1
# radisson blu                                ro              1
# qiryat ono                                  il              1
# qld                                         au              1
# quakers hill, nsw                           au              1
# quebec                                      ca              1
# quebec city                                 ca              1
# quentin zoo                                 de              1
# querceta                                    it              1
# querença                                    pt              1
# quriat-tivon                                il              1
# raard                                       nl              1
# rabieh                                      lb              1
# radcliffe on trent, nottinghamshire, uk     gb              1
# noordwelle                                  nl              1
# noordlaren                                  nl              1
# saint benoit                                fr              1
# marly le roi                                fr              1
# masonville, co 80541                        us              1
# matassino reggello                          it              1
# matlaske, norwich                           gb              1
# matsue-shimane                              jp              1
# maunaloa                                    us              1
# mc                                          mc              1
# mclean va                                   us              1
# medford ma                                  us              1
# meer/hoogstraten                            be              1
# meerijnen                                   nl              1
# meerkerk                                    nl              1
# meersel-dreef                               be              1
# meerstad                                    nl              1
# meeuwen-gruitrode                           be              1
# megara                                      gr              1
# meikirch                                    ch              1
# meito-ku,nagoya                             jp              1
# melbourne, victoria                         au              1
# melissant                                   nl              1
# melrose north                               za              1
# menlo park, ca                              us              1
# merksem - antwerpen                         be              1
# merseyside                                  gb              1
# mesnil enouche                              fr              1
# mestecko                                    sk              1
# mestre-venezia                              it              1
# metslawier                                  nl              1
# marupe                                      lv              1
# markenbinnen                                nl              1
# madison, wi                                 us              1
# marietta ga                                 us              1
# madrid spain                                es              1
# maebashi-shi                                jp              1
# magill north                                au              1
# mahone bay                                  ca              1
# maisons alfort                              fr              1
# makkum fr                                   nl              1
# mallnitz                                    at              1
# mallorca                                    es              1
# mallorca llucmajor                          es              1
# malmo                                       se              1
# manalapan                                   us              1
# manhattan montana                           us              1
# manila city                                 ph              1
# manly sydney                                au              1
# manor farm house                            gb              1
# manteca, ca                                 us              1
# mantinge                                    nl              1
# manuel b. gonnet                            br              1
# mapo-gu                                     kr              1
# maracaibo estado zulia                      ve              1
# maranello (modena)                          it              1
# marcq en baroeul                            fr              1
# maren kessel                                nl              1
# margny sur matz                             fr              1
# maria hoop                                  nl              1
# marianske lazne                             cz              1
# marienheem                                  nl              1
# mevaseret zion                              il              1
# mexico d.f.                                 mx              1
# mexico df                                   mx              1
# mexico stad                                 mx              1
# minsk, belarus                              by              1
# minstead                                    gb              1
# mitaka city                                 jp              1
# mitischy                                    ru              1
# mittelhäusern                               ch              1
# mjolby                                      se              1
# modiin                                      il              1
# moehlin                                     ch              1
# moerbeke-waas                               be              1
# moergestel                                  nl              1
# moerkapelle                                 nl              1
# moerkeke-waas                               be              1
# moerkoev                                    dk              1
# moerstraten                                 nl              1
# molenaarsgraaf                              nl              1
# molenwaard                                  nl              1
# molinazzo di monteggio                      ch              1
# molkwerum                                   nl              1
# mollie-margot                               ch              1
# mon chique                                  pt              1
# moncton nb                                  ca              1
# mondorf                                     lu              1
# mondorf les bains                           lu              1
# monleon magnoac                             fr              1
# monroe ny                                   us              1
# monroe township                             us              1
# monroe twp nj                               us              1
# minneapolis, mn                             us              1
# minneapolis minnesota                       us              1
# minato-ku, tokyo                            jp              1
# midlaren                                    nl              1
# mexico, cdmx                                mx              1
# miami, fl                                   us              1
# miami, florida                              us              1
# michaelchurch escley, hereford              gb              1
# mid-level                                   hk              1
# mid-levels, hong kong                       us              1
# middelaar                                   nl              1
# middelburg zld                              nl              1
# midden beemster                             nl              1
# middletown springs                          us              1
# midgham                                     gb              1
# midland, tx                                 us              1
# midlevels                                   hk              1
# minami-ku,fukuoka-shi                       jp              1
# miercurea ciuc                              ro              1
# mies                                        ch              1
# milahvanstrijp@hotmail.com                  nl              1
# milano mi                                   it              1
# mildura vic                                 au              1
# mililani hawaii                             us              1
# millbrook, torpoint                         gb              1
# millen-selfkant                             de              1
# millingen aan de rijn                       nl              1
# millsboro delaware                          us              1
# milly sur therain                           fr              1
# mils                                        at              1
# madison, wisconsin                          us              1
# madeid                                      es              1
# mont de marsan                              fr              1
# liege                                       be              1
# lignol le chateau                           fr              1
# lillois                                     be              1
# lime springs ia                             us              1
# limhamn                                     se              1
# lincoln, ca                                 us              1
# lincs                                       gb              1
# linde dr                                    nl              1
# line                                        cz              1
# linz, österreich                            at              1
# lioessens                                   nl              1
# liptovsky mikulas                           sk              1
# lisboa                                      nl              1
#                                             pt              1
# lisboa - portugal                           pt              1
# lit et mixe                                 fr              1
# lithuania                                   lt              1
# lititz pa                                   us              1
# little barrington                           gb              1
# little rock, arkansas                       us              1
# little walden, saffron walden               gb              1
# livingston, nj                              us              1
# livry gargan                                fr              1
# ljubjana ?entvid                            si              1
# ljussens                                    nl              1
# lkjlk                                       jp              1
# llandudno junction                          gb              1
# lo barnechea, santiago                      cl              1
# lierderholthuis                             nl              1
# lidköping, sverige                          se              1
# mack?s                                      se              1
# lidingoe                                    se              1
# leawood ks                                  us              1
# leerbroek                                   nl              1
# leermens                                    nl              1
# lefkosia                                    cy              1
# leidem                                      nl              1
# leidrn                                      nl              1
# leidschendam                                nl              1
# leidschendam-voorburg                       nl              1
# leipzig sachsen                             de              1
# lekkerkerk                                  nl              1
# lemele                                      nl              1
# lemelerveld                                 nl              1
# lemesos                                     cy              1
# lemieux                                     ca              1
# lemwerder                                   de              1
# lengel                                      nl              1
# lepelstraat(nb)                             nl              1
# les diablerets                              ch              1
# les essarts le roi                          fr              1
# les jardins d'artémis                       fr              1
# les noes                                    fr              1
# lettele                                     nl              1
# leuvenheim                                  nl              1
# level 7                                     be              1
# lewedorp                                    nl              1
# lexmond                                     nl              1
# lichtaard                                   nl              1
# lodz                                        pl              1
# loegstrup                                   dk              1
# loendersloot                                nl              1
# loenen a/d vecht                            nl              1
# los cerralbos                               es              1
# lotissement la sauvagine ii                 fr              1
# louestault                                  fr              1
# lower largo                                 gb              1
# lucaswolde                                  nl              1
# ludwigshafen                                de              1
# lufingen                                    ch              1
# luinjeberd                                  nl              1
# luins                                       ch              1
# lussan ( 30580 )                            fr              1
# lutherstadt wittenberg                      de              1
# lutjewinkel                                 nl              1
# luxembourg city                             lu              1
# luxemburg-stad                              lu              1
# lyme, new hampshire                         us              1
# lymm warrington                             gb              1
# lyngby                                      dk              1
# lyon/ paris                                 fr              1
# lódz                                        pl              1
# m202                                        us              1
# maak uw keuze                               be              1
# maarkedal                                   be              1
# maarssenbroek                               nl              1
# maasbommel                                  nl              1
# machida city                                jp              1
# machida-city, tokyo                         jp              1
# machida-shi, tokyo                          jp              1
# los angeles, california                     us              1
# los angeles, ca                             us              1
# los angeles , california                    us              1
# london sw9 0el                              gb              1
# loenen a/de vecht                           nl              1
# loenen aan de vecht                         ne              1
#                                             nl              1
# loenen ad vecht                             nl              1
# loenen gld                                  nl              1
# loenersloot                                 nl              1
# loerbeek                                    nl              1
# lollum                                      nl              1
# lommiswil                                   ch              1
# londo, ontario                              ca              1
# london se24 9hh                             gb              1
# london sw11 5hh                             gb              1
# london, groot brittanië                     gb              1
# los alamos, nm                              us              1
# london, ontario                             ca              1
# london, uk                                  gb              1
# lonender                                    nl              1
# long island                                 us              1
# longerhouw                                  nl              1
# longtown, carlisle                          gb              1
# loo gld                                     nl              1
# loosdrecht                                  nl              1
# loosdrecht, nederland                       nl              1
# loosdrect                                   nl              1
# lords valley                                us              1
# loriana (oviedo)                            es              1
# monroe twp, nj                              us              1
# montagnole (73000)                          fr              1
# noordgouwe                                  nl              1
# new richmond wisconsin                      us              1
# new yersey                                  us              1
# new york                                    us              1
# new york new york                           us              1
# new york ny                                 us              1
# new york ny 10075                           us              1
# new york, new york                          us              1
# new york, ny                                us              1
# new zealand                                 nz              1
# newbury park                                us              1
# newfield, ny.                               us              1
# newlyn, cornwall                            gb              1
# newman lake                                 us              1
# newmarket, ontario                          ca              1
# newport beach, california                   us              1
# newport coast ca                            us              1
# newton center                               us              1
# newton highlands                            us              1
# newton, ma                                  us              1
# newyork                                     us              1
# nh                                          nl              1
# nibbixwoud                                  nl              1
# nieder-ohmen                                de              1
# niehove                                     nl              1
# nieuw buinen                                nl              1
# nieuw namen                                 nl              1
# nieuw scheemda                              nl              1
# nieuw vannep                                nl              1
# new territories, hong kong                  hk              1
# new milford, ct                             us              1
# neißemünde                                  de              1
# new lebanon, ny                             us              1
# neo faliro piraeus                          gr              1
# ...
# diest-webbekom                              be              1
# dieverbrug                                  nl              1
# dijkstraat                                  nl              1
# dilsen-stokkem                              be              1
# dinteloord gemeente steenbergen             nl              1
# dinxperlo                                   nl              1
# diphoorn                                    nl              1
# dirrietz                                    nl              1
# district of columbia                        us              1
# divonne les bains                           fr              1
# eygelshoven                                 nl              1
# fadeeva, 2                                  ru              1
# hawally                                     kw              1
# graft-de rijp                               nl              1
# granada hills                               us              1
# grand-lancy                                 ch              1
# grathem                                     nl              1
# great cambourne                             gb              1
# great cheverell                             gb              1
# great glen leicester                        gb              1
# great lakes                                 us              1
# green bay, wisconsin                        us              1
# greensboro, nc                              us              1
# greenwich, london                           gb              1
# greenwood, indiana                          us              1
# greer, south carolina                       us              1
# greonterp                                   nl              1
# grimentz                                    ch              1
# grinder                                     no              1
# groenlo                                     nl              1
# groet                                       nl              1
# grootebroek                                 nl              1
# gross enzersdorf                            at              1
# gross groenau                               de              1
# großburgwedel                               de              1
# grubbenvorst                                nl              1
# guecho                                      es              1
# guetersloh                                  de              1
# guidonia -montecelio                        it              1
# gullholmen                                  se              1
# gurgaon                                     in              1
# gramsbergen                                 nl              1
# grabownica                                  pl              1
# glenageary dublin                           ie              1
# graauw                                      nl              1
# glenview, il                                us              1
# glenview, kentucky 40025                    us              1
# gloskow                                     pl              1
# gloucestershire                             gb              1
# glucholazy                                  pl              1
# glyfada attica                              gr              1
# godlinze                                    nl              1
# godollo                                     hu              1
# goeilaard                                   be              1
# goeje                                       kr              1
# goengahuizen                                nl              1
# goerlitz                                    de              1
# goettingen                                  de              1
# goetzingen                                  lu              1
# goingarijp                                  nl              1
# goleta, ca                                  us              1
# gomez                                       us              1
# gonnet                                      ar              1
# gooise meren                                nl              1
# gordon park, brisbane                       au              1
# goreme nevsehir                             tr              1
# goring, reading                             gb              1
# gorzow wlkp                                 pl              1
# gossau hz                                   ch              1
# gostingen                                   lu              1
# goudriaan                                   nl              1
# goyang-si, gyeonggi-do                      kr              1
# gwacheon-si                                 kr              1
# gwanak-gu, seoul                            kr              1
# gyeonggi-do                                 kr              1
# gyeonggi-do,                                kr              1
# hameau de morgiou                           fr              1
# hamilton parish                             bm              1
# hamilton qld                                au              1
# hamilton, ontario                           ca              1
# hantumhuizen                                nl              1
# har halutz                                  il              1
# harbertonford                               gb              1
# harderwijk gld                              nl              1
# hardinxveld                                 nl              1
# hardinxveld giessendam                      nl              1
# hardinxveld-giessendam                      nl              1
# haren gem haren                             nl              1
# haren gn                                    nl              1
# haren nb                                    nl              1
# haringhuizen                                nl              1
# harku vald                                  ee              1
# harrison, new jersey                        us              1
# harrow, middlesex                           gb              1
# haskerdijken                                nl              1
# hassfurt                                    de              1
# hastings on hudson                          us              1
# haule                                       nl              1
# hauptwil                                    ch              1
# hausen am albis                             ch              1
# havelock, on                                ca              1
# havelterberg                                nl              1
# hawalli                                     kw              1
# hamamatsu,shizuoka                          jp              1
# hamamatsu, shizuoka                         jp              1
# halle saale                                 de              1
# hachioji-shi.tokyo                          jp              1
# gyor                                        hu              1
# h                                           nl              1
# h.i.ambacht                                 nl              1
# h.k., hong kong                             hk              1
# h302                                        us              1
# haarle gem hellendoorn                      nl              1
# haarlemmerliede                             nl              1
# haarlemmermeer                              nl              1
# haarlo                                      nl              1
# haarzuilens                                 nl              1
# hachioji,tokyo                              jp              1
# hachioji-city tokyo                         jp              1
# hadano-shi                                  jp              1
# hallandale, fl usa                          us              1
# hadiya                                      kw              1
# haenwijck                                   nl              1
# haeundae, busan                             kr              1
# hafnarfjordur                               is              1
# hafrffgord                                  no              1
# hafrsfjord                                  no              1
# hagersten                                   se              1
# haghorst                                    nl              1
# hague                                       nl              1
# halfweg nh                                  nl              1
# halifax, ns                                 ca              1
# halisex                                     gb              1
# glendale, az                                us              1
# glen ellyn, illinois                        us              1
# fairhope, alabama                           us              1
# fort worth texas                            us              1
# fox glacier                                 nz              1
# fpo                                         us              1
# fpo ae                                      us              1
# fpo, ae                                     us              1
# frankfrut                                   de              1
# frankfurt                                   de              1
#                                             nl              1
# frankfurt a.m.                              de              1
# frankfurt amin                              de              1
# frankfurt(m)                                de              1
# frankfurt-am-main                           de              1
# frankfurt/main                              de              1
# franklin, north carolina                    us              1
# frasnacht tg                                ch              1
# frederiksoord                               nl              1
# fredonia, ny                                us              1
# frei                                        no              1
# freiburg i. br.                             de              1
# freiburg im breisgau                        de              1
# freigericht                                 de              1
# frejus                                      fr              1
# frickenhausen am main                       de              1
# friedberg (hessen)                          de              1
# frutillar                                   cl              1
# fuerstenwalde spree                         de              1
# fuessen                                     de              1
# funabashi city                              jp              1
# fort worth, tx                              us              1
# fort gratiot, michigan                      us              1
# glen allen, va                              us              1
# formerum                                    nl              1
# fairlee, vt                                 us              1
# falcade                                     it              1
# falls church, virginia                      us              1
# farvagny                                    ch              1
# feeding hills                               us              1
# feerwerd                                    nl              1
# felben-wellhausen                           ch              1
# fernwald                                    de              1
# ferwoude                                    nl              1
# filothei athens                             gr              1
# firenze                                     it              1
# flat 3 glenwood                             gb              1
# flat 4                                      gb              1
# flavigny sur ozerain                        fr              1
# fletching                                   gb              1
# flitwick, bedfordshire                      gb              1
# floersheim                                  de              1
# florianópolis (sc)                          br              1
# florianópolis, santa catarina, brasil       br              1
# floro                                       no              1
# fochteloo                                   nl              1
# folsgare                                    nl              1
# fontenay aux roses                          fr              1
# fontenay sous bois                          fr              1
# fontenoy le chateau                         fr              1
# fontrieu                                    fr              1
# forli                                       it              1
# funabashi, chiba                            jp              1
# fuscaldo cosenza                            it              1
# fyllingsdalen                               no              1
# g                                           nl              1
# genemuiden                                  nl              1
# geneve                                      ch              1
#                                             fr              1
# geneve 6                                    ch              1
# gentofte                                    dk              1
# gerakas, athens                             gr              1
# germany                                     de              1
# gernika                                     es              1
# gernlinden                                  de              1
# geulle                                      nl              1
# gfcfxfdxdfy                                 nl              1
# gharghur                                    mt              1
# ghaziabad                                   in              1
# gibson island                               us              1
# gieszhübl                                   at              1
# gijon                                       es              1
# gijón - asturias                            es              1
# gimposi                                     kr              1
# girija                                      lv              1
# gironde                                     fr              1
# givat ada                                   il              1
# givat hen                                   il              1
# givrins                                     ch              1
# gjettum                                     no              1
# gladwyne                                    us              1
# glane                                       nl              1
# glastonbury, ct usa                         us              1
# gemlik/bursa                                tr              1
# gelselaar                                   nl              1
# gellicum                                    nl              1
# garminge                                    nl              1
# g                                           ua              1
# g.nam@operaballet.nl                        nl              1
# gaanderen                                   nl              1
# gaastmeer                                   nl              1
# gabriola, bc                                ca              1
# gainesville, fl                             us              1
# galgary                                     nl              1
# gallarate (varese)                          it              1
# galleria dpt                                kr              1
# gapinge                                     nl              1
# garching b. münchen                         de              1
# gardabaer                                   is              1
# garnwerd                                    nl              1
# gelderswoude                                nl              1
# garsthuizen                                 nl              1
# gauw                                        nl              1
# gava                                        es              1
# gda?sk                                      pl              1
# gdansk                                      pl              1
# geaz                                        at              1
# geen                                        ca              1
# geerdijk                                    nl              1
# geervliet                                   nl              1
# geesteren gld                               nl              1
# geestland                                   de              1
# geilenkirchen-tripsrath                     de              1
# øster assels                                no              1
# Name: count, dtype: int64

# %%
# reset index and export as parquet
raw = raw.reset_index(drop=True)
#raw.to_parquet('../../data/processed/raw_clean.parquet')
